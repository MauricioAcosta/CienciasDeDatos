# %% [markdown]
# # Introducción a la Ciencia de Datos 2019-1
# ## Docente: Nelson Enrique Vera
# ### Estudiantes:
# ### Leidy Marcela Aldana Burgos
# - Código: 20151020019 - LeidyMarcelaAldana@gmail.com
# ### Andrés Mauricio Acosta Pulido
# - Código: 20142020111 - AndresAcostaPulido96@gmail.com
#
# #### Graficas a utilizar Line plot, Bar, Pie

# %%
# Importando librerias
import pandas as pd
from matplotlib.ticker import FuncFormatter
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Dataset descargado de: 
# https://www.datos.gov.co/Cultura/Publicaciones-del-Instituto-Caro-y-Cuervo-actualiz/hms6-a2pb
# Este dataset contiene las publicaciones del Instituto Caro y Cuervo en sus diferentes formatos
dataset=pd.read_csv('Diagn_sticos_emitidos0.csv') #Tomado de: https://www.datos.gov.co/Ciencia-Tecnolog-a-e-Innovaci-n/Principales-enfermedades-dermatologicas/7u2k-ibcf
dataset
# Out:
#      Unnamed: 0       fecha  edad sexo codigocie10  \
# 0             0  26/08/2013    18    M  0000L708.1
# 1             1  20/05/2013    67    F  000000L814
# 2             2  23/07/2012    18    M  000000L209
# 3             3  20/06/2013    37    F  0000D229.1
# 4             4  29/05/2012    44    M  0000I831.1
# 5             5  23/06/2011    53    F  00000L82.1
# 6             6  14/12/2012    58    F  000L578.11
# 7             7  18/07/2012    14    F  000000L305
# 8             8  19/04/2012    20    F  000000L639
# 9             9  23/05/2011    59    F  000000L235
# 10           10  29/06/2011    55    F  0000L570.1
# 11           11  02/10/2012    31    F  0000L219.1
# 12           12  19/06/2012    17    F  000000L639
# 13           13  11/10/2011    25    M  0000L708.1
# 14           14  08/10/2012    18    F  0000L708.2
# 15           15  19/01/2012    23    M  000000L700
# 16           16  03/04/2013    64    M  000000L719
# ...

# %% [markdown]
# ## Grafica Line Plot

# %%
dataset1=dataset[0:100]
plt.plot(dataset1['edad'])

# %% [markdown]
# ## Grafica Bar charts

# %%
dataset2=dataset[0:50]
dataset2['diagnostico'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Grafica Pie Chart

# %%
dataset3=dataset[0:10]
porcentaje=dataset3['diagnostico'].value_counts()

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

data = porcentaje
nombresEnfermedades = porcentaje.index


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))

ax.legend(wedges, nombresEnfermedades,
          title="Enfermendades",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.2, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Enfermedad mas frecuente")

plt.show()
